# %% [markdown]
# # 1 Backpropagation in a simple neural network
# ## a) Dataset
# Visualization of dataset.

# %%
from three_layer_neural_network import *

# %%
X, y = generate_data()
plt.scatter(X[:, 0], X[:, 1], s=40, c=y, cmap=plt.cm.Spectral)
plt.show()

# %% [markdown]
# ## e) Train network with different activation functions
# ### Tanh

# %%
model = NeuralNetwork(nn_input_dim=2, nn_hidden_dim=3 , nn_output_dim=2, actFun_type='tanh')
model.fit_model(X,y,epsilon=0.01)
model.visualize_decision_boundary(X,y)
# Out:
# Loss after iteration 0: 0.505247
# Loss after iteration 1000: 0.073904
# Loss after iteration 2000: 0.084900
# Loss after iteration 3000: 0.106849
# Loss after iteration 4000: 0.082975
# Loss after iteration 5000: 0.089406
# Loss after iteration 6000: 0.088858
# Loss after iteration 7000: 0.095273
# Loss after iteration 8000: 0.096119
# Loss after iteration 9000: 0.102892
# Loss after iteration 10000: 0.111927
# Loss after iteration 11000: 0.110523
# Loss after iteration 12000: 0.118813
# Loss after iteration 13000: 0.126431
# Loss after iteration 14000: 0.124551
# Loss after iteration 15000: 0.133517
# Loss after iteration 16000: 0.141987
# Loss after iteration 17000: 0.138563
# Loss after iteration 18000: 0.146402
# Loss after iteration 19000: 0.153511

# %% [markdown]
# ### Sigmoid

# %%
model = NeuralNetwork(nn_input_dim=2, nn_hidden_dim=3 , nn_output_dim=2, actFun_type='sigmoid')
model.fit_model(X,y,epsilon=0.0001)
model.visualize_decision_boundary(X,y)
# Out:
# Loss after iteration 0: 0.737714
# Loss after iteration 1000: 0.430222
# Loss after iteration 2000: 0.350653
# Loss after iteration 3000: 0.329289
# Loss after iteration 4000: 0.320105
# Loss after iteration 5000: 0.316436
# Loss after iteration 6000: 0.315060
# Loss after iteration 7000: 0.314578
# Loss after iteration 8000: 0.314462
# Loss after iteration 9000: 0.314521
# Loss after iteration 10000: 0.314693
# Loss after iteration 11000: 0.314958
# Loss after iteration 12000: 0.315312
# Loss after iteration 13000: 0.315756
# Loss after iteration 14000: 0.316294
# Loss after iteration 15000: 0.316932
# Loss after iteration 16000: 0.317673
# Loss after iteration 17000: 0.318521
# Loss after iteration 18000: 0.319479
# Loss after iteration 19000: 0.320549

# %% [markdown]
# ### ReLU

# %%
model = NeuralNetwork(nn_input_dim=2, nn_hidden_dim=3 , nn_output_dim=2, actFun_type='relu')
model.fit_model(X,y)
model.visualize_decision_boundary(X,y)
# Out:
# Loss after iteration 0: 0.619102
# Loss after iteration 1000: 0.230616
# Loss after iteration 2000: 0.229973
# Loss after iteration 3000: 0.224994
# Loss after iteration 4000: 0.225030
# Loss after iteration 5000: 0.225045
# Loss after iteration 6000: 0.225645
# Loss after iteration 7000: 0.225998
# Loss after iteration 8000: 0.225604
# Loss after iteration 9000: 0.225738
# Loss after iteration 10000: 0.225854
# Loss after iteration 11000: 0.226012
# Loss after iteration 12000: 0.225660
# Loss after iteration 13000: 0.225468
# Loss after iteration 14000: 0.225534
# Loss after iteration 15000: 0.225641
# Loss after iteration 16000: 0.225755
# Loss after iteration 17000: 0.225878
# Loss after iteration 18000: 0.226022
# Loss after iteration 19000: 0.225590

# %% [markdown]
# ### More hidden units with Tanh

# %%
model = NeuralNetwork(nn_input_dim=2, nn_hidden_dim=20 , nn_output_dim=2, actFun_type='tanh')
model.fit_model(X,y)
model.visualize_decision_boundary(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-f0e49b0417bc> in <module>
#       1 model = NeuralNetwork(nn_input_dim=2, nn_hidden_dim=20 , nn_output_dim=2, actFun_type='tanh')
# ----> 2 model.fit_model(X,y)
#       3 model.visualize_decision_boundary(X,y)
#
# ~\Documents\BCM\courses\Y2T1\DeepLearning\assignments\Assignment1\three_layer_neural_network.py in fit_model(self, X, y, epsilon, num_passes, print_loss)
#     181             self.feedforward(X, lambda x: self.actFun(x, type=self.actFun_type))
#     182             # Backpropagation
# --> 183             dW1, dW2, db1, db2 = self.backprop(X, y)
#     184             # Add derivatives of regularization terms (b1 and b2 don't have regularization terms)
#     185             dW2 += self.reg_lambda * self.W2
#
# ~\Documents\BCM\courses\Y2T1\DeepLearning\assignments\Assignment1\three_layer_neural_network.py in backprop(self, X, y)
#     163         dW2 = np.dot(self.a1.T, (self.probs - y_onehot))
#     164         db2 = np.ones(num_examples).T.dot(self.probs - y_onehot)
# --> 165         dW1 = X.T.dot((self.probs - y_onehot).dot(self.W2.T).dot(self.diff_actFun(self.a1, self.actFun_type)))
#     166         db1 = np.ones(num_examples).T.dot((self.probs - y_onehot).dot(self.W2.T).dot(self.diff_actFun(self.a1, self.actFun_type)))
#     167         return dW1, dW2, db1, db2
#
# ValueError: shapes (200,20) and (200,20) not aligned: 20 (dim 1) != 200 (dim 0)

# %% [markdown]
# ## f) Train a Deep Network

# %%
import n_layer_neural_network

# %%
model = n_layer_neural_network.DeepNeuralNetwrok(n_hidden=5, input_dim=2, hidden_dim=3, output_dim=2, actFun_type='tanh')

model.fit_model(X,y,epsilon=0.00002)

model.visualize_decision_boundary(X,y)
# Out:
# Loss after iteration 0: 0.756570
# Loss after iteration 1000: 0.691495
# Loss after iteration 2000: 0.391357
# Loss after iteration 3000: 0.350077
# Loss after iteration 4000: 0.319283
# Loss after iteration 5000: 0.297540
# Loss after iteration 6000: 0.295902
# Loss after iteration 7000: 0.314645
# Loss after iteration 8000: 0.262400
# Loss after iteration 9000: 0.221431
# Loss after iteration 10000: 0.151187
# Loss after iteration 11000: 0.093058
# Loss after iteration 12000: 0.086437
# Loss after iteration 13000: 0.084610
# Loss after iteration 14000: 0.084032
# Loss after iteration 15000: 0.083792
# Loss after iteration 16000: 0.083690
# Loss after iteration 17000: 0.083638
# Loss after iteration 18000: 0.083444
# Loss after iteration 19000: 0.082564

# %%
model = n_layer_neural_network.DeepNeuralNetwrok(n_hidden=1, input_dim=2, hidden_dim=3, output_dim=2, actFun_type='tanh')

model.fit_model(X,y,epsilon=0.0005)

model.visualize_decision_boundary(X,y)
# Out:
# Loss after iteration 0: 0.758836
# Loss after iteration 1000: 0.210777
# Loss after iteration 2000: 0.077994
# Loss after iteration 3000: 0.070170
# Loss after iteration 4000: 0.067738
# Loss after iteration 5000: 0.066900
# Loss after iteration 6000: 0.066689
# Loss after iteration 7000: 0.066711
# Loss after iteration 8000: 0.066823
# Loss after iteration 9000: 0.066979
# Loss after iteration 10000: 0.067172
# Loss after iteration 11000: 0.067427
# Loss after iteration 12000: 0.067790
# Loss after iteration 13000: 0.068236
# Loss after iteration 14000: 0.068610
# Loss after iteration 15000: 0.068798
# Loss after iteration 16000: 0.068817
# Loss after iteration 17000: 0.068726
# Loss after iteration 18000: 0.068578
# Loss after iteration 19000: 0.068408

# %%
model = n_layer_neural_network.DeepNeuralNetwrok(n_hidden=5, input_dim=2, hidden_dim=10, output_dim=2, actFun_type='tanh')

model.fit_model(X,y,epsilon=0.0005)

model.visualize_decision_boundary(X,y)
# Out:
# Loss after iteration 0: 0.642642
# Loss after iteration 1000: 0.075906
# Loss after iteration 2000: 0.060366
# Loss after iteration 3000: 0.046032
# Loss after iteration 4000: 0.031966
# Loss after iteration 5000: 0.063732
# Loss after iteration 6000: 0.013238
# Loss after iteration 7000: 0.012387
# Loss after iteration 8000: 0.012751
# Loss after iteration 9000: 0.011375
# Loss after iteration 10000: 0.011639
# Loss after iteration 11000: 0.011599
# Loss after iteration 12000: 0.011184
# Loss after iteration 13000: 0.010542
# Loss after iteration 14000: 0.011355
# Loss after iteration 15000: 0.009558
# Loss after iteration 16000: 0.004211
# Loss after iteration 17000: 0.004024
# Loss after iteration 18000: 0.003958
# Loss after iteration 19000: 0.003916

# %%
from sklearn import datasets
np.random.seed(0)
X, y = datasets.make_circles(100, noise=0.05)

# %%
model = n_layer_neural_network.DeepNeuralNetwrok(n_hidden=5, input_dim=2, hidden_dim=10, output_dim=2, actFun_type='tanh')

model.fit_model(X,y,epsilon=0.001)

model.visualize_decision_boundary(X,y)
# Out:
# Loss after iteration 0: 0.701803
# Loss after iteration 1000: 0.135404
# Loss after iteration 2000: 0.082295
# Loss after iteration 3000: 0.046055
# Loss after iteration 4000: 0.388605
# Loss after iteration 5000: 0.016813
# Loss after iteration 6000: 0.014829
# Loss after iteration 7000: 0.014331
# Loss after iteration 8000: 0.013975
# Loss after iteration 9000: 0.013666
# Loss after iteration 10000: 0.013382
# Loss after iteration 11000: 0.013113
# Loss after iteration 12000: 0.012855
# Loss after iteration 13000: 0.012606
# Loss after iteration 14000: 0.012365
# Loss after iteration 15000: 0.012130
# Loss after iteration 16000: 0.011902
# Loss after iteration 17000: 0.011680
# Loss after iteration 18000: 0.011463
# Loss after iteration 19000: 0.011252

# %%
model = n_layer_neural_network.DeepNeuralNetwrok(n_hidden=1, input_dim=2, hidden_dim=3, output_dim=2, actFun_type='tanh')

model.fit_model(X,y,epsilon=0.01)

model.visualize_decision_boundary(X,y)
# Out:
# Loss after iteration 0: 0.697695
# Loss after iteration 1000: 0.936296
# Loss after iteration 2000: 0.557259
# Loss after iteration 3000: 0.564724
# Loss after iteration 4000: 0.647287
# Loss after iteration 5000: 0.706167
# Loss after iteration 6000: 0.742978
# Loss after iteration 7000: 0.774569
# Loss after iteration 8000: 0.804840
# Loss after iteration 9000: 0.835696
# Loss after iteration 10000: 0.865551
# Loss after iteration 11000: 0.893950
# Loss after iteration 12000: 0.920744
# Loss after iteration 13000: 0.945956
# Loss after iteration 14000: 0.969891
# Loss after iteration 15000: 0.992767
# Loss after iteration 16000: 1.014099
# Loss after iteration 17000: 1.033661
# Loss after iteration 18000: 1.051528
# Loss after iteration 19000: 1.067814
